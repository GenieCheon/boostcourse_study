# %%
# !move "C:\Users\winne\Downloads\도로교통공단_사망 교통사고 정보_20211231.csv" .
# Out:
#         1개 파일을 이동했습니다.

# %%
# %ls
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 06B9-E2F5
#
#  C:\Users\winne\git\Study 디렉터리
#
# 2022-10-28  오후 11:53    <DIR>          .
# 2022-10-28  오후 11:53    <DIR>          ..
# 2022-10-28  오후 11:27    <DIR>          .ipynb_checkpoints
# 2022-10-28  오전 01:21             5,151 1. 데이터 분석 환경 구성.ipynb
# 2022-10-28  오전 06:57           108,844 2. 데이터 분석 준비하기.ipynb
# 2022-10-28  오후 11:52               959 file-path.ipynb
# 2022-10-28  오후 11:40           459,343 도로교통공단_사망 교통사고 정보_20211231.csv
#                4개 파일             574,297 바이트
#                3개 디렉터리  97,869,344,768 바이트 남음

# %%
import pandas as pd

# %%
pd.read_csv("도로교통공단_사망 교통사고 정보_20211231.csv")
# Out:
#       �߻���         �߻�����Ͻ� �־� ����  ����ڼ�  �λ��ڼ�  �߻��ڼ�  ����ڼ�.1  \
# 0      2021  2021-01-01 03:00  ��   ��       1       3       0         3
# 1      2021  2021-01-01 09:00  ��   ��       1       0       0         0
# 2      2021  2021-01-01 15:00  ��   ��       1       0       0         0
# 3      2021  2021-01-01 19:00  ��   ��       1       0       0         0
# 4      2021  2021-01-01 21:00  ��   ��       1       0       0         0
# ...     ...               ...  ..  ...     ...     ...     ...       ...
# 2811   2021  2021-12-31 16:00  ��   ��       1       0       0         0
# 2812   2021  2021-12-31 17:00  ��   ��       1       0       0         0
# 2813   2021  2021-12-31 18:00  ��   ��       1       0       0         0
# 2814   2021  2021-12-31 19:00  ��   ��       1       0       0         0
# 2815   2021  2021-12-31 21:00  ��   ��       1       0       0         0
#
#       �λ�Ű��ڼ� �߻����õ�  ...  �������        �����ڹ������� ��������_��з�  \
# ...

# %%
# ()안에서 shift + tab 키를 누르시면 도움말을 보실 수 있습니다.
pd.read_csv("도로교통공단_사망 교통사고 정보_20211231.csv", encoding="cp949")
# Out:
#        발생년            발생년월일시 주야 요일  사망자수  부상자수  중상자수  경상자수  부상신고자수 발생지시도  ...  \
# 0     2021  2021-01-01 03:00  야  금     1     3     0     3       0    경북  ...
# 1     2021  2021-01-01 09:00  주  금     1     0     0     0       0    충남  ...
# 2     2021  2021-01-01 15:00  주  금     1     0     0     0       0    강원  ...
# 3     2021  2021-01-01 19:00  야  금     1     0     0     0       0    전남  ...
# 4     2021  2021-01-01 21:00  야  금     1     0     0     0       0    경기  ...
# ...    ...               ... .. ..   ...   ...   ...   ...     ...   ...  ...
# 2811  2021  2021-12-31 16:00  주  금     1     0     0     0       0    경북  ...
# 2812  2021  2021-12-31 17:00  주  금     1     0     0     0       0    제주  ...
# 2813  2021  2021-12-31 18:00  야  금     1     0     0     0       0    강원  ...
# 2814  2021  2021-12-31 19:00  야  금     1     0     0     0       0    경북  ...
# 2815  2021  2021-12-31 21:00  야  금     1     0     0     0       0    강원  ...
#
# ...
